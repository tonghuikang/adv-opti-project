# %%
import datetime
from viz import *

# datestring = datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%SZ")

# %%
# datestring

# %% [markdown]
# # Variant 1

# %%
results = '''
X[14,26,29] 1
X[15,26,66] 1
X[16,26,39] 1
X[17,26,62] 1
X[18,26,1] 1
X[19,26,44] 1
X[20,33,9] 1
X[21,33,29] 1
X[22,33,49] 1
X[23,32,38] 1
X[24,32,60] 1
X[25,32,1] 1
X[26,32,84] 1
X[41,20,1] 1
X[42,20,36] 1
X[43,17,42] 1
X[44,17,60] 1
X[45,32,9] 1
X[46,6,50] 1
X[47,6,5] 1
X[48,6,54] 1
X[49,1,29] 1
X[50,12,1] 1
X[51,12,35] 1
X[52,17,9] 1
X[53,17,50] 1
X[58,17,36] 1
X[59,17,67] 1
X[60,21,67] 1
X[61,21,84] 1
'''.strip()
results = [list(map(int,result.split("]")[0].split("[")[1].split(','))) for result in results.split('\n')]
# results # job_ix, venue_ix, time_ix

# %%
df_output = parse_results(results)
organized_timetable = organize_timetable(df_output)
plot_organised_timetable(organized_timetable, show_fig=True)

# %%
superprefix = "Variant 1"
analyse_related_features(df_output, folder_output="./task-3-second-half/{}".format(superprefix.lower().replace(" ","-")), 
                         title_prefix=superprefix + " - ")

# %% [markdown]
# # Variant 2

# %%
results = '''
X[14,26,20] 1
X[15,26,68] 1
X[16,26,1] 1
X[17,26,78] 1
X[18,26,10] 1
X[19,26,49] 1
X[20,33,5] 1
X[21,33,28] 1
X[22,33,59] 1
X[23,32,5] 1
X[24,32,78] 1
X[25,32,10] 1
X[26,32,59] 1
X[41,20,5] 1
X[42,20,68] 1
X[43,17,41] 1
X[44,17,51] 1
X[45,32,32] 1
X[46,6,59] 1
X[47,6,36] 1
X[48,6,66] 1
X[49,1,56] 1
X[50,12,20] 1
X[51,12,44] 1
X[52,17,9] 1
X[53,17,62] 1
X[58,17,28] 1
X[59,17,78] 1
X[60,21,10] 1
X[61,21,28] 1
'''.strip()
results = [list(map(int,result.split("]")[0].split("[")[1].split(','))) for result in results.split('\n')]
# results # job_ix, venue_ix, time_ix

# %%
df_output = parse_results(results)
organized_timetable = organize_timetable(df_output)
plot_organised_timetable(organized_timetable, show_fig=True)

# %%
superprefix = "Variant 2"
analyse_related_features(df_output, folder_output="./task-3-second-half/{}".format(superprefix.lower().replace(" ","-")), 
                         title_prefix=superprefix + " - ")

# %% [markdown]
# # Variant 3

# %%
results = '''
X[14,26,28] 1
X[15,26,68] 1
X[16,26,3] 1
X[17,26,54] 1
X[18,26,10] 1
X[19,26,63] 1
X[20,33,42] 1
X[21,33,68] 1
X[22,33,87] 1
X[23,32,43] 1
X[24,32,54] 1
X[25,32,10] 1
X[26,32,85] 1
X[41,20,10] 1
X[42,20,36] 1
X[43,17,34] 1
X[44,17,52] 1
X[45,32,5] 1
X[46,6,85] 1
X[47,6,10] 1
X[48,6,66] 1
X[49,1,28] 1
X[50,12,36] 1
X[51,12,63] 1
X[52,17,5] 1
X[53,17,85] 1
X[58,17,41] 1
X[59,17,61] 1
X[60,21,5] 1
X[61,21,68] 1
'''.strip()
results = [list(map(int,result.split("]")[0].split("[")[1].split(','))) for result in results.split('\n')]
# results # job_ix, venue_ix, time_ix

# %%
df_output = parse_results(results)
organized_timetable = organize_timetable(df_output)
plot_organised_timetable(organized_timetable, show_fig=True)

# %%
superprefix = "Variant 3"
analyse_related_features(df_output, folder_output="./task-3-second-half/{}".format(superprefix.lower().replace(" ","-")), 
                         title_prefix=superprefix + " - ")

# %% [markdown]
# # Combined

# %%
results = '''
X[14,26,29] 1
X[15,26,51] 1
X[16,26,40] 1
X[17,26,66] 1
X[18,26,3] 1
X[19,26,34] 1
X[20,33,9] 1
X[21,33,51] 1
X[22,33,61] 1
X[23,32,9] 1
X[24,32,67] 1
X[25,32,3] 1
X[26,32,29] 1
X[41,20,3] 1
X[42,20,29] 1
X[43,17,3] 1
X[44,17,29] 1
X[45,32,43] 1
X[46,6,65] 1
X[47,6,39] 1
X[48,6,61] 1
X[49,1,51] 1
X[50,12,9] 1
X[51,12,35] 1
X[52,17,43] 1
X[53,17,61] 1
X[58,17,9] 1
X[59,17,34] 1
X[60,21,3] 1
X[61,21,29] 1
'''.strip()
results = [list(map(int,result.split("]")[0].split("[")[1].split(','))) for result in results.split('\n')]
# results # job_ix, venue_ix, time_ix

# %%
df_output = parse_results(results)
organized_timetable = organize_timetable(df_output)
plot_organised_timetable(organized_timetable, show_fig=True)

# %%
superprefix = "Combined"
analyse_related_features(df_output, folder_output="./task-3-second-half/{}".format(superprefix.lower().replace(" ","-")), 
                         title_prefix=superprefix + " - ")

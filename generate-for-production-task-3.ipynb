# %%
import datetime
from viz import *

# datestring = datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%SZ")

# %%
# datestring

# %% [markdown]
# # Variant 1

# %%
results = '''
X[1,26,29] 1
X[2,26,49] 1
X[3,26,34] 1
X[4,26,67] 1
X[5,26,1] 1
X[6,26,44] 1
X[7,33,9] 1
X[8,33,50] 1
X[9,33,61] 1
X[10,32,9] 1
X[11,32,54] 1
X[12,32,1] 1
X[13,32,29] 1
X[27,20,1] 1
X[28,20,29] 1
X[29,17,35] 1
X[30,17,60] 1
X[31,12,86] 1
X[32,32,5] 1
X[33,6,54] 1
X[34,6,9] 1
X[35,6,83] 1
X[36,1,30] 1
X[37,12,1] 1
X[38,12,36] 1
X[39,17,9] 1
X[40,17,54] 1
X[54,17,43] 1
X[55,17,67] 1
X[56,21,67] 1
X[57,21,84] 1
'''.strip()
results = [list(map(int,result.split("]")[0].split("[")[1].split(','))) for result in results.split('\n')]
# results # job_ix, venue_ix, time_ix

# %%
df_output = parse_results(results)
organized_timetable = organize_timetable(df_output)
plot_organised_timetable(organized_timetable, show_fig=True)

# %%
superprefix = "variant-1"
analyse_related_features(df_output, folder_output="./task-3/{}".format(superprefix), 
                         title_prefix=superprefix)

# %% [markdown]
# # Variant 2

# %%
results = '''
X[1,26,10] 1
X[2,26,68] 1
X[3,26,28] 1
X[4,26,63] 1
X[5,26,20] 1
X[6,26,59] 1
X[7,33,44] 1
X[8,33,68] 1
X[9,33,83] 1
X[10,32,5] 1
X[11,32,78] 1
X[12,32,40] 1
X[13,32,59] 1
X[27,20,9] 1
X[28,20,50] 1
X[29,17,1] 1
X[30,17,37] 1
X[31,12,56] 1
X[32,32,20] 1
X[33,6,49] 1
X[34,6,5] 1
X[35,6,54] 1
X[36,1,33] 1
X[37,12,1] 1
X[38,12,37] 1
X[39,17,20] 1
X[40,17,54] 1
X[54,17,10] 1
X[55,17,44] 1
X[56,21,20] 1
X[57,21,29] 1
'''.strip()
results = [list(map(int,result.split("]")[0].split("[")[1].split(','))) for result in results.split('\n')]
# results # job_ix, venue_ix, time_ix

# %%
df_output = parse_results(results)
organized_timetable = organize_timetable(df_output)
plot_organised_timetable(organized_timetable, show_fig=True)

# %%
superprefix = "variant-2"
analyse_related_features(df_output, folder_output="./task-3/{}".format(superprefix), 
                         title_prefix=superprefix)

# %% [markdown]
# # Variant 3

# %%
results = '''
X[1,26,28] 1
X[2,26,68] 1
X[3,26,10] 1
X[4,26,54] 1
X[5,26,3] 1
X[6,26,63] 1
X[7,33,38] 1
X[8,33,68] 1
X[9,33,87] 1
X[10,32,10] 1
X[11,32,36] 1
X[12,32,5] 1
X[13,32,85] 1
X[27,20,9] 1
X[28,20,28] 1
X[29,17,37] 1
X[30,17,62] 1
X[31,12,87] 1
X[32,32,30] 1
X[33,6,66] 1
X[34,6,5] 1
X[35,6,85] 1
X[36,1,52] 1
X[37,12,9] 1
X[38,12,36] 1
X[39,17,5] 1
X[40,17,33] 1
X[54,17,10] 1
X[55,17,42] 1
X[56,21,5] 1
X[57,21,64] 1
'''.strip()
results = [list(map(int,result.split("]")[0].split("[")[1].split(','))) for result in results.split('\n')]
# results # job_ix, venue_ix, time_ix

# %%
df_output = parse_results(results)
organized_timetable = organize_timetable(df_output)
plot_organised_timetable(organized_timetable, show_fig=True)

# %%
superprefix = "variant-3"
analyse_related_features(df_output, folder_output="./task-3/{}".format(superprefix), 
                         title_prefix=superprefix)

# %% [markdown]
# # Combined

# %%
results = '''
X[1,26,34] 1
X[2,26,62] 1
X[3,26,29] 1
X[4,26,67] 1
X[5,26,3] 1
X[6,26,39] 1
X[7,33,9] 1
X[8,33,43] 1
X[9,33,56] 1
X[10,32,9] 1
X[11,32,29] 1
X[12,32,3] 1
X[13,32,38] 1
X[27,20,3] 1
X[28,20,29] 1
X[29,17,9] 1
X[30,17,29] 1
X[31,12,56] 1
X[32,32,43] 1
X[33,6,67] 1
X[34,6,39] 1
X[35,6,63] 1
X[36,1,51] 1
X[37,12,3] 1
X[38,12,67] 1
X[39,17,40] 1
X[40,17,67] 1
X[54,17,3] 1
X[55,17,34] 1
X[56,21,9] 1
X[57,21,61] 1
'''.strip()
results = [list(map(int,result.split("]")[0].split("[")[1].split(','))) for result in results.split('\n')]
# results # job_ix, venue_ix, time_ix

# %%
df_output = parse_results(results)
organized_timetable = organize_timetable(df_output)
plot_organised_timetable(organized_timetable, show_fig=True)

# %%
superprefix = "combined"
analyse_related_features(df_output, folder_output="./task-3/{}".format(superprefix), 
                         title_prefix=superprefix)
